# %% [markdown]
# <a href="https://colab.research.google.com/github/dspalacios26/Laboratorio6/blob/main/detec_fig.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Evidencia 3
#
# Detección de formas: Se usará Python 3 Google Compute Engine backend con la herramienta de Google Colab y sus respectivas librerías para la detección de formas.

# %%
# inicio de importación de librerías
# %matplotlib inline

import cv2
import matplotlib.pyplot as plt

# leer imagen original
image = plt.imread('tapa.jpg')
plt.imshow(image);

# %%
# convertir imagen a escala de grises
grayimg = cv2.cvtColor(image, cv2.COLOR_RGB2GRAY)
CMAP_GRAY = 'gray'
plt.imshow(grayimg, CMAP_GRAY);

# %%
import numpy as np

# aplicar filtro borroso
blurred = cv2.blur(grayimg, (11, 11))
plt.imshow(blurred, CMAP_GRAY);

# %%
# detectar bordes
edges = cv2.Canny(blurred, 1, 50)
plt.imshow(edges, CMAP_GRAY);

# %%
# dilatar bordes detectados
kernel = np.ones((20, 20), np.uint8)
dilated = cv2.dilate(edges, kernel, iterations=1)
plt.imshow(dilated, CMAP_GRAY);

# %%
count, hierarchy = cv2.findContours(dilated.copy(), cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_NONE)
len(count)
# Out:
# 21
